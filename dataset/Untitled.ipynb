# %%
import pandas as pd

# Read CSV with ; separator
df = pd.read_csv('Recipes_50k_1.csv', sep=';')
df = df.drop(columns=['Unnamed: 0'])

# Save CSV with , separator
df.to_csv('Recipes_50k.csv', sep=',', index=False)

print("✅ Converted CSV saved as 'test_comma.csv'")
# Out:
# ✅ Converted CSV saved as 'test_comma.csv'

# %%
# Out:
#                                                     name      id  minutes  \
# 0                             cream cheese press cookies   80097      150
# 1                               homemade vanilla pudding  372497       17
# 2      iraqi halwa of toasted rice flour  halawat tim...  442708       30
# 3          grilled chicken skewers with red pepper pesto  488707       25
# 4                                 primavera potato salad  420079       25
# ...                                                  ...     ...      ...
# 49995                       cranberry sauce     diabetic  216774       25
# 49996                 moroccan chicken and raisins for 2  338342       65
# 49997        garam masala dipping sauce with pita wedges  247410       65
# 49998                         cilantro lime mexican rice  385056       25
# 49999                                      basic popover  365164       45
#
#        contributor_id   submitted  \
# 0               85310  2004-01-02
# ...

# %%
df = pd.read_csv('Recipes_50k_1.csv', sep=';').
